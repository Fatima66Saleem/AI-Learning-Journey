# %%
name = "Fatima"
age = 20

# %%
print(f"My name is {name} and i am {age} years old")
# Out:
# My name is Fatima and i am 20 years old

# %%
length = 10
width = 5

# %%
print(f"The area of rectangle is {length * width} square units")
# Out:
# The area of rectangle is 50 square units

# %%
name = "Fatima"
city = "Pakpattan"
print(f"My name is {name} and i live in {city}.")
# Out:
# My name is Fatima and i live in Pakpattan.

# %%
a = 15
b = 4
print(f"Sum: {a+b} \nDifference: {a-b} \nproduct: {a*b}")
# Out:
# Sum: 19
# Difference: 11
# product: 60

# %%
radius = 7
print(f"The area of circle is: {3.14 * radius * radius}")
# Out:
# The area of circle is: 153.86

# %%
marks = 450
total_marks = 500
print(f"you percentage is {(marks / total_marks)* 100}")
# Out:
# you percentage is 90.0

# %%
celsius = 30
print(f"The temperature in Fahrenheit is {(celsius * 9/5) + 32}")
# Out:
# The temperature in Fahrenheit is 86.0

# %%
item = "Notebook"
price = 120
quantity = 3
print(f"You bought {quantity} Notebook(s) for a total of Rs. {price * quantity}")
# Out:
# You bought 3 Notebook(s) for a total of Rs. 360

# %%
temp = 25.6789
print(f"{temp:.2f}")
# Out:
# 25.68
