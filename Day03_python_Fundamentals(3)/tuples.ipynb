# %%
value = (1, 2, 2, 3, 5, 3, 2, 6)
print(type(value))
# Out:
# <class 'tuple'>

# %%
value = (1, 2, 2, 3, 5, 3, 2, 6)
print(value[7])
# Out:
# 6

# %%
value = (1, 2, 2, 3, 5, 3, 2, 6)
print(value[2 : 6])
# Out:
# (2, 3, 5, 3)

# %%
print(value.index(2)) # .index returns the first occurance index
# Out:
# 1

# %%
print(value.count(2))  # .count return the total no of occurance
# Out:
# 3

# %%
val = (1) # simple tuple value cause error  so we use , after the value
type(val)
# Out:
# int

# %%
val = (1,) # simple tuple value cause error  so we use , after the value
type(val)
# Out:
# tuple
