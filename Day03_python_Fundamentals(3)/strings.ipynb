# %%
word = "Python" # string is used to stire sequence of characters
print(len(word)) # length of string
# Out:
# 6

# %%
word1 = "Fatima"
Word2 = "Saleem"
print(word1 + Word2) # '+' is used in string to concatinate the strings.
# Out:
# FatimaSaleem

# %%
word1 = "Fatima"
print(word[3])
# Out:
# h

# %%
#  slicing in string
word = "I am intern at Bitsol Technologies"
print(word[4 : 9]) # 4 is starting index and default value of starting index is 0 and 9 is ending index and it has len(string) as default value
# Out:
#  inte

# %%
word1 = "I am intern at Bitsol Technologies"
print(word1[-11:-4]) # negative indexing
# Out:
# echnolo
